# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrianaLavy/testrepo/blob/main/ImportacionyPresentaci%C3%B3ndeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTACIÓN DE LIBRERIAS/BIBLIOTECAS

# %%
import pandas as pd # importar librerías para el uso de dataframes
import numpy as np # librería para trabajar con matrices
import seaborn as sns # librería para visualizaciones de datos

# %% [markdown]
# CARGA DE DATOS A UN DATAFRAME

# %%
df_cyberwow=pd.read_excel("/content/CONJUNTO DE DATOS - CYBERWOW RIPLEY.xlsx")

# %% [markdown]
# PRESENTACIÓN DE LAS PRIMERAS FILAS DEL DATAFRAME

# %%
df_cyberwow.head() # primeras 5 filas
# Out:
#    HORA_VENTA    FECHA_VENTA_HORA    MES FECHA_VENTA DIA_VENTA  \
# 0          22 2022-04-22 22:29:13  ABRIL  2022-04-22       Vie
# 1          21 2022-04-22 21:45:36  ABRIL  2022-04-22       Vie
# 2          20 2022-04-22 20:33:42  ABRIL  2022-04-22       Vie
# 3          23 2022-04-22 23:43:42  ABRIL  2022-04-22       Vie
# 4          23 2022-04-22 23:27:23  ABRIL  2022-04-22       Vie
#
#   FECHA_DESPACHO_PROMETIDA JORNADA_DESP  ORDEN_COMPRA                     CUD  \
# 0               2022-04-26            S    44328869.0  0600050001240975540002
# 1               2022-04-26            S    44328293.0  0600050001240914480202
# 2               2022-04-25           RT    44321439.0  0600050001240769530001
# 3               2022-04-27           RT    44339807.0  0600050001241212800001
# 4               2022-04-27           RT    44339583.0  0600050001241188820001
#
#    NRO_BOLETA  ...   FECHA_VENTA_H_RSV FECHA_VENTA_RSV FECHA_ENTREGADO_BT_TR  \
# ...

# %%
df_cyberwow.head(18) # primeras 18 filas
# Out:
#     HORA_VENTA    FECHA_VENTA_HORA    MES FECHA_VENTA DIA_VENTA  \
# 0           22 2022-04-22 22:29:13  ABRIL  2022-04-22       Vie
# 1           21 2022-04-22 21:45:36  ABRIL  2022-04-22       Vie
# 2           20 2022-04-22 20:33:42  ABRIL  2022-04-22       Vie
# 3           23 2022-04-22 23:43:42  ABRIL  2022-04-22       Vie
# 4           23 2022-04-22 23:27:23  ABRIL  2022-04-22       Vie
# 5           23 2022-04-22 23:01:39  ABRIL  2022-04-22       Vie
# 6           21 2022-04-22 21:37:57  ABRIL  2022-04-22       Vie
# 7           21 2022-04-22 21:19:32  ABRIL  2022-04-22       Vie
# 8           20 2022-04-22 20:29:09  ABRIL  2022-04-22       Vie
# 9           17 2022-04-22 17:30:48  ABRIL  2022-04-22       Vie
# 10          14 2022-04-22 14:13:40  ABRIL  2022-04-22       Vie
# 11          18 2022-04-20 18:39:58  ABRIL  2022-04-20       Mie
# 12          18 2022-04-20 18:07:47  ABRIL  2022-04-20       Mie
# 13          20 2022-04-20 20:56:31  ABRIL  2022-04-20       Mie
# ...

# %% [markdown]
# PRESENTACIÓN DE LAS ÚLTIMAS FILAS DEL DATAFRAME

# %%
df_cyberwow.tail()
# Out:
#        HORA_VENTA    FECHA_VENTA_HORA    MES FECHA_VENTA DIA_VENTA  \
# 18030          23 2022-07-07 23:30:20  JULIO  2022-07-07       Jue
# 18031          17 2022-07-07 17:15:41  JULIO  2022-07-07       Jue
# 18032          15 2022-07-07 15:50:04  JULIO  2022-07-07       Jue
# 18033          23 2022-07-07 23:09:36  JULIO  2022-07-07       Jue
# 18034          12 2022-07-07 12:19:27  JULIO  2022-07-07       Jue
#
#       FECHA_DESPACHO_PROMETIDA JORNADA_DESP  ORDEN_COMPRA  \
# 18030               2022-07-11           RT    46011698.0
# 18031               2022-07-09           RT    46122789.0
# 18032               2022-07-08           RT    46114751.0
# 18033               2022-07-09           RT    46106139.0
# 18034               2022-07-08           RT    46090582.0
#
#                           CUD  NRO_BOLETA  ...   FECHA_VENTA_H_RSV  \
# 18030  0600050001284663070201        1589  ... 2022-07-07 23:30:20
# 18031  0600050001283716540001        3651  ... 2022-07-07 17:15:41
# ...

# %%
df_cyberwow.tail(10)
# Out:
#        HORA_VENTA    FECHA_VENTA_HORA    MES FECHA_VENTA DIA_VENTA  \
# 18025          17 2022-07-07 17:23:35  JULIO  2022-07-07       Jue
# 18026          15 2022-07-07 15:48:49  JULIO  2022-07-07       Jue
# 18027          23 2022-07-07 23:05:29  JULIO  2022-07-07       Jue
# 18028          22 2022-07-07 22:25:45  JULIO  2022-07-07       Jue
# 18029           8 2022-07-07 08:31:29  JULIO  2022-07-07       Jue
# 18030          23 2022-07-07 23:30:20  JULIO  2022-07-07       Jue
# 18031          17 2022-07-07 17:15:41  JULIO  2022-07-07       Jue
# 18032          15 2022-07-07 15:50:04  JULIO  2022-07-07       Jue
# 18033          23 2022-07-07 23:09:36  JULIO  2022-07-07       Jue
# 18034          12 2022-07-07 12:19:27  JULIO  2022-07-07       Jue
#
#       FECHA_DESPACHO_PROMETIDA JORNADA_DESP  ORDEN_COMPRA  \
# 18025               2022-07-08           RT    46120871.0
# 18026               2022-07-08           RT    46112964.0
# ...

# %% [markdown]
# TAMAÑO Y CONTENIDO DEL CONJUNTO DE DATOS

# %%
df_cyberwow.shape # dimensiones del dataframe
# Out:
# (18035, 162)

# %%
df_cyberwow.size # tamaño del dataframe
# Out:
# 2921670

# %%
df_cyberwow.info() # información general del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18035 entries, 0 to 18034
# Columns: 162 entries, HORA_VENTA to FECHA_MIN_PROMESA
# dtypes: datetime64[ns](33), float64(12), int64(17), object(100)
# memory usage: 22.3+ MB

# %%
df_cyberwow.isnull() # muestra los nulos como true
# Out:
#        HORA_VENTA  FECHA_VENTA_HORA    MES  FECHA_VENTA  DIA_VENTA  \
# 0           False             False  False        False      False
# 1           False             False  False        False      False
# 2           False             False  False        False      False
# 3           False             False  False        False      False
# 4           False             False  False        False      False
# ...           ...               ...    ...          ...        ...
# 18030       False             False  False        False      False
# 18031       False             False  False        False      False
# 18032       False             False  False        False      False
# 18033       False             False  False        False      False
# 18034       False             False  False        False      False
#
#        FECHA_DESPACHO_PROMETIDA  JORNADA_DESP  ORDEN_COMPRA    CUD  \
# 0                         False         False         False  False
# ...

# %%
df_cyberwow.isnull().sum() # muestra la suma de nulos
# Out:
# HORA_VENTA               0
# FECHA_VENTA_HORA         0
# MES                      0
# FECHA_VENTA              0
# DIA_VENTA                0
#                      ...
# FECHA_DESP_NPS       17670
# BK_COLOR_D_VENTA         0
# TIPO_COMENTARIO      17670
# TIPO_PROMESA_CORP        0
# FECHA_MIN_PROMESA        1
# Length: 162, dtype: int64

# %%
df_cyberwow.dtypes
# Out:
# HORA_VENTA                    int64
# FECHA_VENTA_HORA     datetime64[ns]
# MES                          object
# FECHA_VENTA          datetime64[ns]
# DIA_VENTA                    object
#                           ...
# FECHA_DESP_NPS       datetime64[ns]
# BK_COLOR_D_VENTA             object
# TIPO_COMENTARIO              object
# TIPO_PROMESA_CORP            object
# FECHA_MIN_PROMESA    datetime64[ns]
# Length: 162, dtype: object

# %% [markdown]
# RESUMEN ESTADISTICA DESCRIPTIVA BÁSICA

# %%
df_cyberwow.describe()
# Out:
#          HORA_VENTA  ORDEN_COMPRA    NRO_BOLETA   CLIENTE_DNI    CODIGO_VTA  \
# count  18035.000000  1.803400e+04  18035.000000  1.803500e+04  1.803500e+04
# mean      14.736180  4.505747e+07   4059.757971  5.170728e+07  2.030442e+12
# std        6.305575  1.680728e+06   2901.365036  3.739555e+08  2.867859e+10
# min        0.000000  0.000000e+00      0.000000  2.346600e+04  2.004131e+12
# 25%       11.000000  4.419100e+07   1403.000000  3.298817e+07  2.004286e+12
# 50%       16.000000  4.584054e+07   3697.000000  4.434658e+07  2.013267e+12
# 75%       20.000000  4.599724e+07   6442.000000  7.076429e+07  2.065284e+12
# max       23.000000  4.625098e+07   9998.000000  2.060340e+10  2.088173e+12
#
#        COD_SUC_RESERVA      NRO_GUIA  COD_SUC_DESPACHO      UNIDADES  \
# count     18035.000000  1.757100e+04      18035.000000  18035.000000
# mean      20026.566676  7.294054e+10      12363.808206      1.661602
# std           6.272828  2.073208e+12       9300.593179      2.049349
# ...

# %%
df_cyberwow.min()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# HORA_VENTA                             0
# FECHA_VENTA_HORA     2022-04-18 00:03:19
# MES                                ABRIL
# FECHA_VENTA          2022-04-18 00:00:00
# DIA_VENTA                            Jue
#                             ...
# FECHA_ENCUESTA       2022-04-20 00:00:00
# FECHA_DESP_NPS       2022-04-19 00:00:00
# BK_COLOR_D_VENTA                 #B3B3B3
# TIPO_PROMESA_CORP                   +72H
# FECHA_MIN_PROMESA    2022-04-19 00:00:00
# Length: 151, dtype: object

# %%
df_cyberwow.columns
# Out:
# Index(['HORA_VENTA', 'FECHA_VENTA_HORA', 'MES', 'FECHA_VENTA', 'DIA_VENTA',
#        'FECHA_DESPACHO_PROMETIDA', 'JORNADA_DESP', 'ORDEN_COMPRA', 'CUD',
#        'NRO_BOLETA',
#        ...
#        'FECHA_VENTA_H_RSV', 'FECHA_VENTA_RSV', 'FECHA_ENTREGADO_BT_TR',
#        'ETQ_NPS_ENCUESTA', 'FECHA_ENCUESTA', 'FECHA_DESP_NPS',
#        'BK_COLOR_D_VENTA', 'TIPO_COMENTARIO', 'TIPO_PROMESA_CORP',
#        'FECHA_MIN_PROMESA'],
#       dtype='object', length=162)

# %% [markdown]
# GRAFICOS

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,8

# %%
sns.displot(data=df_cyberwow,x="LIMA_METROPOLITANA",color="purple")

# %%
sns.displot(data=df_cyberwow,x="DIVISION")

# %%
sns.barplot(data=df_cyberwow,x="TIPO_TARJETA",y="VENTA_CON_IGV")

# %%
sns.barplot(data=df_cyberwow,x="MODALIDAD_DESPACHO",y="VENTA_CON_IGV")

# %%
df_cyberwow_cuanti=pd.read_excel("/content/CONJUNTO DE DATOS - CYBERWOW RIPLEY.xlsx",usecols=["VENTA_CON_IGV","MES","LIMA_METROPOLITANA","DIVISION"])

# %%
df_cyberwow_cuanti.describe()
# Out:
#        VENTA_CON_IGV
# count   18035.000000
# mean     1442.329692
# std      1865.367029
# min         0.000000
# 25%       179.000000
# 50%       849.000000
# 75%      1949.000000
# max     28990.000000

# %%
sns.barplot(data=df_cyberwow_cuanti,x="VENTA_CON_IGV",y="MES")

# %%
sns.barplot(data=df_cyberwow_cuanti,x="DIVISION",y="VENTA_CON_IGV")

# %%
df_cyberwow_cuali=pd.read_excel("/content/CONJUNTO DE DATOS - CYBERWOW RIPLEY.xlsx",usecols=["LIMA_METROPOLITANA","MODALIDAD_DESPACHO","TIPO_TARJETA","DIVISION","PAIS_DISTRITO"])

# %%
df_cyberwow_cuali.describe()
# Out:
#        MODALIDAD_DESPACHO      PAIS_DISTRITO LIMA_METROPOLITANA DIVISION  \
# count               18035              18035              18035    18035
# unique                  3                146                  2       10
# top      Retiro en Tienda  SANTIAGO DE SURCO               LIMA     D113
# freq                10664               1001              13452     7661
#
#           TIPO_TARJETA
# count            18024
# unique              11
# top     Tarjeta Ripley
# freq             12056

# %%
sns.displot(data=df_cyberwow_cuali,x="LIMA_METROPOLITANA")

# %%
sns.displot(data=df_cyberwow_cuali,x="MODALIDAD_DESPACHO",color="yellow")

# %%
sns.displot(data=df_cyberwow_cuali,x="DIVISION",color="green")
